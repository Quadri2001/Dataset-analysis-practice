# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('heroes.csv', sep=",")
df
# Out:
#      Sr. No. Rank    Class                     Name  Gender  \
# 0          1  S-1  S-Class                   Blast     Male
# 1          2  S-2  S-Class               Tatsumaki   Female
# 2          3  S-3  S-Class              Silver Fang    Male
# 3          4  S-4  S-Class           Atomic Samurai    Male
# 4          5  S-5  S-Class            Child Emperor    Male
# ..       ...  ...      ...                      ...     ...
# 133      134  ???    Staff   Special Committee Girl  Female
# 134      135  ???    Staff                  Shizuka  Female
# 135      136  ???    Staff                  Zeimeet    Male
# 136      137  ???    Staff  Z Branch Committee Girl  Female
# 137      138  ???    Staff        Z Branch Operator  Female
#
#                                              Abilities
# 0    ['Superhuman Physical Prowess', 'Portal Creati...
# 1                                    ['Psychokinesis']
# 2    ['Superhuman Physical Prowess', 'Master Martia...
# ...

# %%
df.head(10)
# top 10 Rows
# Out:
#    Sr. No.  Rank    Class            Name  Gender  \
# 0        1   S-1  S-Class          Blast     Male
# 1        2   S-2  S-Class      Tatsumaki   Female
# 2        3   S-3  S-Class     Silver Fang    Male
# 3        4   S-4  S-Class  Atomic Samurai    Male
# 4        5   S-5  S-Class   Child Emperor    Male
# 5        6   S-6  S-Class    Metal Knight    Male
# 6        7   S-7  S-Class            King    Male
# 7        8   S-8  S-Class       Zombieman    Male
# 8        9   S-9  S-Class    Drive Knight    Male
# 9       10  S-10  S-Class         Pig God    Male
#
#                                            Abilities
# 0  ['Superhuman Physical Prowess', 'Portal Creati...
# 1                                  ['Psychokinesis']
# 2  ['Superhuman Physical Prowess', 'Master Martia...
# 3  ['Superhuman Physical Prowess', 'Master Swords...
# 4                               ['Genius Intellect']
# 5                               ['Genius Intellect']
# ...

# %%
df.tail(10)
# Last 10 rows
# Out:
#      Sr. No. Rank  Class                     Name  Gender Abilities
# 128      129  ???  Staff                  Narinki    Male       NaN
# 129      130  ???  Staff                 Sekingar    Male       NaN
# 130      131  ???  Staff        Shelter Nr.7 Girl  Female       NaN
# 131      132  ???  Staff                    Sitch    Male       NaN
# 132      133  ???  Staff       Some Important Guy    Male       NaN
# 133      134  ???  Staff   Special Committee Girl  Female       NaN
# 134      135  ???  Staff                  Shizuka  Female       NaN
# 135      136  ???  Staff                  Zeimeet    Male       NaN
# 136      137  ???  Staff  Z Branch Committee Girl  Female       NaN
# 137      138  ???  Staff        Z Branch Operator  Female       NaN

# %%
df.shape
# Shape of the Dataset(Number of Rows and Columns)
# Out:
# (138, 6)

# %%
print('Number of Rows', df.shape[0])
print('Number of Columns', df.shape[1])
# Out:
# Number of Rows 138
# Number of Columns 6

# %%
# Getting info. about the dataset like total numbers of rows and columns, datatypes of each and memory requirement 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sr. No.    138 non-null    int64
#  1   Rank       138 non-null    object
#  2   Class      138 non-null    object
#  3   Name       138 non-null    object
#  4   Gender     138 non-null    object
#  5   Abilities  50 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 6.6+ KB

# %%
# Missing values

# %%
print('Any missing values?', df.isnull().values.any())
# Out:
# Any missing values? True

# %%
df.isnull().sum()
# Out:
# Sr. No.       0
# Rank          0
# Class         0
# Name          0
# Gender        0
# Abilities    88
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#missing values in %

# %%
per_missing = df.isnull().sum()*100/len(df)
per_missing
# Out:
# Sr. No.       0.000000
# Rank          0.000000
# Class         0.000000
# Name          0.000000
# Gender        0.000000
# Abilities    63.768116
# dtype: float64

# %%
#Drop all the missing values

# %%
df.dropna(axis=0)
# Out:
#     Sr. No.  Rank    Class                   Name  Gender  \
# 0         1   S-1  S-Class                 Blast     Male
# 1         2   S-2  S-Class             Tatsumaki   Female
# 2         3   S-3  S-Class            Silver Fang    Male
# 3         4   S-4  S-Class         Atomic Samurai    Male
# 4         5   S-5  S-Class          Child Emperor    Male
# 5         6   S-6  S-Class           Metal Knight    Male
# 6         7   S-7  S-Class                   King    Male
# 7         8   S-8  S-Class              Zombieman    Male
# 8         9   S-9  S-Class           Drive Knight    Male
# 9        10  S-10  S-Class                Pig God    Male
# 10       11  S-11  S-Class  Supperalloy Darkshine    Male
# 11       12  S-12  S-Class           Watchdog Man    Male
# 12       13  S-13  S-Class           Flashy flash    Male
# 13       14  S-14  S-Class                  Genos    Male
# 14       15  S-15  S-Class              Metal Bat    Male
# ...

# %%
#Check for duplicate data

# %%
dup_df= df.duplicated().any()

# %%
print("Are there any duplicate values?", dup_df)
# Out:
# Are there any duplicate values? False

# %%
df= df.drop_duplicates()
df
#to drop duplicates
# Out:
#      Sr. No. Rank    Class                     Name  Gender  \
# 0          1  S-1  S-Class                   Blast     Male
# 1          2  S-2  S-Class               Tatsumaki   Female
# 2          3  S-3  S-Class              Silver Fang    Male
# 3          4  S-4  S-Class           Atomic Samurai    Male
# 4          5  S-5  S-Class            Child Emperor    Male
# ..       ...  ...      ...                      ...     ...
# 133      134  ???    Staff   Special Committee Girl  Female
# 134      135  ???    Staff                  Shizuka  Female
# 135      136  ???    Staff                  Zeimeet    Male
# 136      137  ???    Staff  Z Branch Committee Girl  Female
# 137      138  ???    Staff        Z Branch Operator  Female
#
#                                              Abilities
# 0    ['Superhuman Physical Prowess', 'Portal Creati...
# 1                                    ['Psychokinesis']
# 2    ['Superhuman Physical Prowess', 'Master Martia...
# ...

# %%
#Get overall statistics about the dataframe

# %%
df.describe()
# Out:
#           Sr. No.
# count  138.000000
# mean    69.500000
# std     39.981246
# min      1.000000
# 25%     35.250000
# 50%     69.500000
# 75%    103.750000
# max    138.000000

# %%
df.describe(include='all')
# Out:
#            Sr. No. Rank    Class    Name Gender              Abilities
# count   138.000000  138      138     138    138                     50
# unique         NaN   93        7     138      2                     45
# top            NaN  ???  A-Class  Blast    Male  ['Enhanced Strength']
# freq           NaN   46       32       1    117                      3
# mean     69.500000  NaN      NaN     NaN    NaN                    NaN
# std      39.981246  NaN      NaN     NaN    NaN                    NaN
# min       1.000000  NaN      NaN     NaN    NaN                    NaN
# 25%      35.250000  NaN      NaN     NaN    NaN                    NaN
# 50%      69.500000  NaN      NaN     NaN    NaN                    NaN
# 75%     103.750000  NaN      NaN     NaN    NaN                    NaN
# max     138.000000  NaN      NaN     NaN    NaN                    NaN

# %%
df.columns
# Out:
# Index(['Sr. No.', 'Rank', 'Class', 'Name', 'Gender', 'Abilities'], dtype='object')

# %%
class_counts = df['Class'].value_counts()
class_counts.plot(kind='bar')
plt.xlabel('Hero Class')
plt.ylabel('Frequency')
plt.title('Distribution of Hero Classes')
plt.show()

# %%
gender_counts = df['Gender'].value_counts()
gender_percentage = gender_counts / gender_counts.sum() * 100
gender_percentage.plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Representation of Heroes')
plt.axis('equal')
plt.show()

# %%
popular_names = df['Name'].value_counts().head(10)
print(popular_names)
# Out:
# Blast         1
# Saturn Man    1
# Angry Man     1
# Horse-Bone    1
# Studless      1
# Poison        1
# Bunbun Man    1
# Hyottoko      1
# Red Nose      1
# Water Gun     1
# Name: Name, dtype: int64

# %%
ability_counts = df['Abilities'].str.split(',').explode().str.strip().value_counts()
ability_counts.plot(kind='bar')
plt.xlabel('Ability')
plt.ylabel('Frequency')
plt.title('Distribution of Hero Abilities')
plt.show()

# %%
gender_class_counts = df.groupby(['Gender', 'Class']).size().unstack()
gender_class_counts.plot(kind='bar', stacked=True)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Hero Classes by Gender')
plt.show()

# %%
ability_corr = df['Abilities'].str.get_dummies(sep=',').corr()
sns.heatmap(ability_corr, cmap='coolwarm', annot=True)
plt.title('Correlation Matrix of Hero Abilities')
plt.show()

# %%
class_top_abilities = df.groupby('Class')['Abilities'].apply(lambda x: x.str.split(',').explode().str.strip().value_counts().head(3))
print(class_top_abilities)
# Out:
# Class
# A-Class  ['Enhanced Strength']             3
#          ['Superhuman Physical Prowess'    2
#          'Enhanced Reflexes']              2
# B-Class  ['Psychokinesis']                 1
# S-Class  ['Superhuman Physical Prowess'    9
#          'Fire Manipulation'               2
#          ['Genius Intellect']              2
# Name: Abilities, dtype: int64

# %%
ability_counts = df['Abilities'].str.split(',').explode().str.strip().value_counts()
rarest_abilities = ability_counts.tail(5)
common_abilities = ability_counts.head(5)
print("Rarest Abilities:\n", rarest_abilities)
print("Common Abilities:\n", common_abilities)
# Out:
# Rarest Abilities:
#  'Self Destruction'            1
# 'Energy Projection'           1
# 'Electricity Manipulation'    1
# 'Flight'                      1
# ['Strength']                  1
# Name: Abilities, dtype: int64
# Common Abilities:
#  ['Superhuman Physical Prowess'    11
# ['Enhanced Strength']              3
# 'Enhanced Reflexes']               2
# ['Marksmanship']                   2
# ['Speed'                           2
# Name: Abilities, dtype: int64
